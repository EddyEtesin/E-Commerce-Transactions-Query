# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\LENOVO\Documents\Web scrapped files\ecommerce_transactions.csv")

# %%
df
# Out:
#        Transaction_ID           User_Name  Age    Country Product_Category  \
# 0                   1            Ava Hall   63     Mexico         Clothing
# 1                   2         Sophia Hall   59      India           Beauty
# 2                   3     Elijah Thompson   26     France            Books
# 3                   4        Elijah White   43     Mexico           Sports
# 4                   5          Ava Harris   48    Germany           Beauty
# ...               ...                 ...  ...        ...              ...
# 49995           49996  Isabella Rodriguez   53      India      Electronics
# 49996           49997           Emma Hall   30     France   Home & Kitchen
# 49997           49998      Isabella Allen   50  Australia           Beauty
# 49998           49999        Olivia Clark   48  Australia          Grocery
# 49999           50000       Olivia Harris   70     Canada           Sports
#
#        Purchase_Amount    Payment_Method Transaction_Date
# ...

# %%
df.head()
# Out:
#    Transaction_ID        User_Name  Age  Country Product_Category  \
# 0               1         Ava Hall   63   Mexico         Clothing
# 1               2      Sophia Hall   59    India           Beauty
# 2               3  Elijah Thompson   26   France            Books
# 3               4     Elijah White   43   Mexico           Sports
# 4               5       Ava Harris   48  Germany           Beauty
#
#    Purchase_Amount Payment_Method Transaction_Date
# 0           780.69     Debit Card       2023-04-14
# 1           738.56         PayPal       2023-07-30
# 2           178.34    Credit Card       2023-09-17
# 3           401.09            UPI       2023-06-21
# 4           594.83    Net Banking       2024-10-29

# %%
df.shape[0]
# Out:
# 50000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    50000 non-null  int64
#  1   User_Name         50000 non-null  object
#  2   Age               50000 non-null  int64
#  3   Country           50000 non-null  object
#  4   Product_Category  50000 non-null  object
#  5   Purchase_Amount   50000 non-null  float64
#  6   Payment_Method    50000 non-null  object
#  7   Transaction_Date  50000 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 3.1+ MB

# %%
#How many unique users are there in the dataset?
df['User_Name'].nunique()
# Out:
# 100

# %%
#What are the unique product categories available in the dataset?
df['Product_Category'].value_counts()
# Out:
# Product_Category
# Toys              6392
# Electronics       6320
# Sports            6312
# Books             6253
# Clothing          6224
# Grocery           6215
# Home & Kitchen    6209
# Beauty            6075
# Name: count, dtype: int64

# %%
#How many transactions were made in each country?
df.groupby('Country')['Transaction_ID'].count()
# Out:
# Country
# Australia    4985
# Brazil       4948
# Canada       5082
# France       4993
# Germany      5047
# India        4996
# Japan        4960
# Mexico       5059
# UK           4951
# USA          4979
# Name: Transaction_ID, dtype: int64

# %%
#Retrieve all transactions where the purchase amount is greater than $500.
df[df['Purchase_Amount'] >500]
# Out:
#        Transaction_ID        User_Name  Age    Country Product_Category  \
# 0                   1         Ava Hall   63     Mexico         Clothing
# 1                   2      Sophia Hall   59      India           Beauty
# 4                   5       Ava Harris   48    Germany           Beauty
# 5                   6    Elijah Harris   51      India             Toys
# 13                 14  Sophia Anderson   26     France             Toys
# ...               ...              ...  ...        ...              ...
# 49993           49994    Isabella Hall   18     France           Beauty
# 49994           49995      Liam Walker   43        USA      Electronics
# 49996           49997        Emma Hall   30     France   Home & Kitchen
# 49997           49998   Isabella Allen   50  Australia           Beauty
# 49999           50000    Olivia Harris   70     Canada           Sports
#
#        Purchase_Amount    Payment_Method Transaction_Date
# ...

# %%
#Find all transactions made by users aged 30 or younger.
df[df['Age'] <= 30]
# Out:
#        Transaction_ID        User_Name  Age    Country Product_Category  \
# 2                   3  Elijah Thompson   26     France            Books
# 6                   7     Oliver Clark   27    Germany   Home & Kitchen
# 10                 11      James Clark   30      Japan   Home & Kitchen
# 12                 13    Sophia Harris   21     France             Toys
# 13                 14  Sophia Anderson   26     France             Toys
# ...               ...              ...  ...        ...              ...
# 49981           49982        Ava Allen   18      Japan      Electronics
# 49984           49985     Oliver Clark   25         UK            Books
# 49986           49987     Sophia White   21  Australia   Home & Kitchen
# 49993           49994    Isabella Hall   18     France           Beauty
# 49996           49997        Emma Hall   30     France   Home & Kitchen
#
#        Purchase_Amount    Payment_Method Transaction_Date
# ...

# %%
#List all transactions where the payment method was "PayPal".
df[df['Payment_Method'] == 'PayPal']
# Out:
#        Transaction_ID       User_Name  Age  Country Product_Category  \
# 1                   2     Sophia Hall   59    India           Beauty
# 12                 13   Sophia Harris   21   France             Toys
# 17                 18   Olivia Harris   47   Brazil            Books
# 18                 19      Noah Lewis   20   France           Beauty
# 21                 22      Emma Clark   58      USA             Toys
# ...               ...             ...  ...      ...              ...
# 49951           49952       Ava Clark   68    India      Electronics
# 49959           49960      Noah Clark   56   France           Sports
# 49963           49964  Isabella White   49  Germany           Sports
# 49964           49965   Olivia Harris   70   Brazil            Books
# 49976           49977   Oliver Harris   69   Mexico             Toys
#
#        Purchase_Amount Payment_Method Transaction_Date
# 1               738.56         PayPal       2023-07-30
# ...

# %%
#What is the total purchase amount for each product category?
df.groupby('Product_Category')['Purchase_Amount'].sum()
# Out:
# Product_Category
# Beauty            3057387.79
# Books             3181897.30
# Clothing          3171225.96
# Electronics       3133965.04
# Grocery           3123579.52
# Home & Kitchen    3108945.78
# Sports            3195335.90
# Toys              3185652.36
# Name: Purchase_Amount, dtype: float64

# %%
#What is the average purchase amount per country?
df.groupby('Country')['Purchase_Amount'].mean()
# Out:
# Country
# Australia    504.495817
# Brazil       506.727474
# Canada       500.656261
# France       509.861644
# Germany      495.827660
# India        501.109430
# Japan        502.482298
# Mexico       500.983528
# UK           499.237154
# USA          510.387672
# Name: Purchase_Amount, dtype: float64

# %%
#Which user has the highest total purchase amount?
highest_user_purchase = df.groupby('User_Name')['Purchase_Amount'].sum()
highest_user_purchase.sort_values(ascending = False).head(10)
# Out:
# User_Name
# Sophia Harris    296354.98
# James Allen      278079.15
# Olivia Hall      277302.09
# Isabella Hall    275798.04
# Noah Anderson    274347.15
# Emma Clark       274313.60
# Ava Clark        273776.79
# Elijah Hall      271861.61
# James Lewis      271007.68
# Ava Hall         268756.73
# Name: Purchase_Amount, dtype: float64

# %%
#Group the data by country and calculate the total purchase amount for each country.
df.groupby('Country')['Purchase_Amount'].sum()
# Out:
# Country
# Australia    2514911.65
# Brazil       2507287.54
# Canada       2544335.12
# France       2545739.19
# Germany      2502442.20
# India        2503542.71
# Japan        2492312.20
# Mexico       2534475.67
# UK           2471723.15
# USA          2541220.22
# Name: Purchase_Amount, dtype: float64

# %%
#Group the data by product category and find the average purchase amount for each category.
df.groupby('Product_Category')['Purchase_Amount'].mean()
# Out:
# Product_Category
# Beauty            503.273710
# Books             508.859316
# Clothing          509.515739
# Electronics       495.880544
# Grocery           502.587212
# Home & Kitchen    500.716022
# Sports            506.231923
# Toys              498.381158
# Name: Purchase_Amount, dtype: float64

# %%
#Group the data by payment method and count the number of transactions for each method.

# %%
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# UPI                 8477
# Cash on Delivery    8434
# Debit Card          8355
# Credit Card         8310
# PayPal              8250
# Net Banking         8174
# Name: count, dtype: int64

# %%
#Sort the transactions by purchase amount in descending order.
df.sort_values(by = "Purchase_Amount", ascending = False  )
# Out:
#        Transaction_ID        User_Name  Age    Country Product_Category  \
# 41014           41015  Sophia Anderson   48     France   Home & Kitchen
# 47132           47133       Liam White   54         UK             Toys
# 36984           36985    Liam Anderson   63  Australia         Clothing
# 19235           19236        Emma Hall   37     France          Grocery
# 20013           20014       Noah White   56      Japan         Clothing
# ...               ...              ...  ...        ...              ...
# 3263             3264     Olivia Clark   45        USA             Toys
# 39067           39068     Elijah Clark   67    Germany      Electronics
# 32290           32291     Elijah Lewis   20      Japan             Toys
# 48527           48528   Noah Rodriguez   68    Germany         Clothing
# 12415           12416    Olivia Walker   23         UK         Clothing
#
#        Purchase_Amount Payment_Method Transaction_Date
# ...

# %%
#Sort the transactions by transaction date in ascending order.
df.sort_values(by = "Purchase_Amount")
# Out:
#        Transaction_ID        User_Name  Age    Country Product_Category  \
# 12415           12416    Olivia Walker   23         UK         Clothing
# 48527           48528   Noah Rodriguez   68    Germany         Clothing
# 32290           32291     Elijah Lewis   20      Japan             Toys
# 3263             3264     Olivia Clark   45        USA             Toys
# 39067           39068     Elijah Clark   67    Germany      Electronics
# ...               ...              ...  ...        ...              ...
# 20013           20014       Noah White   56      Japan         Clothing
# 19235           19236        Emma Hall   37     France          Grocery
# 36984           36985    Liam Anderson   63  Australia         Clothing
# 47132           47133       Liam White   54         UK             Toys
# 41014           41015  Sophia Anderson   48     France   Home & Kitchen
#
#        Purchase_Amount Payment_Method Transaction_Date
# ...

# %%
#Sort the users by their total purchase amount in descending order.
user_purchase  = df.groupby('User_Name')['Purchase_Amount'].sum()
user_purchase.sort_values(ascending = False )
# Out:
# User_Name
# Sophia Harris       296354.98
# James Allen         278079.15
# Olivia Hall         277302.09
# Isabella Hall       275798.04
# Noah Anderson       274347.15
#                       ...
# Elijah Allen        227384.30
# Elijah White        227204.04
# Oliver Rodriguez    221734.83
# Liam White          221275.93
# Isabella Clark      218420.85
# Name: Purchase_Amount, Length: 100, dtype: float64

# %%
#How many transactions were made in the year 2023?
df['Transaction_Date']= pd.to_datetime(df["Transaction_Date"])
df[df['Transaction_Date'].dt.year == 2023]['Transaction_ID'].count()
# Out:
# 20416

# %%
#What is the total purchase amount for each month in 2024?
df_2024  = df[df['Transaction_Date'].dt.year == 2024]
months_2024 =  df.groupby(df_2024['Transaction_Date'].dt.month)['Purchase_Amount'].sum()
months_2024
# Out:
# Transaction_Date
# 1.0     1101023.49
# 2.0     1004235.75
# 3.0     1018957.55
# 4.0     1047109.76
# 5.0     1070447.76
# 6.0     1032452.78
# 7.0     1065266.58
# 8.0     1061115.60
# 9.0     1034725.55
# 10.0    1079380.33
# 11.0    1065021.09
# 12.0    1061061.79
# Name: Purchase_Amount, dtype: float64

# %%
#Find the top 5 days with the highest total purchase amount.
Transaction_days = df.groupby('Transaction_Date')['Purchase_Amount'].sum()
Transaction_days.sort_values(ascending =  False).head(5)
# Out:
# Transaction_Date
# 2024-06-02    48391.31
# 2024-04-26    47940.29
# 2024-01-02    47270.41
# 2023-09-06    47071.11
# 2023-12-27    46899.91
# Name: Purchase_Amount, dtype: float64

# %%
#Which user has made the most transactions?
df.groupby('User_Name')['Transaction_ID'].count().idxmax()
# Out:
# 'Sophia Harris'

# %%
#What is the average purchase amount for users aged 40-50?
df.head()
age_40_50 =  df[(df["Age"] >= 40) & (df["Age"] <= 50)]
age_40_50_average_purchase =  age_40_50["Purchase_Amount"].mean()
age_40_50_average_purchase
# Out:
# 502.6994600267125

# %%
#List all transactions made by a specific user (e.g., "Ava Hall").
df[df["User_Name"] == "Ava Hall"]
# Out:
#        Transaction_ID User_Name  Age Country Product_Category  \
# 0                   1  Ava Hall   63  Mexico         Clothing
# 75                 76  Ava Hall   56  Mexico            Books
# 199               200  Ava Hall   62      UK             Toys
# 305               306  Ava Hall   61   Japan           Beauty
# 389               390  Ava Hall   19  Brazil             Toys
# ...               ...       ...  ...     ...              ...
# 49649           49650  Ava Hall   18  Canada             Toys
# 49723           49724  Ava Hall   70     USA            Books
# 49868           49869  Ava Hall   47  Mexico            Books
# 49952           49953  Ava Hall   23   India           Sports
# 49991           49992  Ava Hall   65   Japan          Grocery
#
#        Purchase_Amount Payment_Method Transaction_Date
# 0               780.69     Debit Card       2023-04-14
# 75              412.67         PayPal       2024-03-20
# ...

# %%
#What is the most popular payment method?
df['Payment_Method'].value_counts().idxmax()
# Out:
# 'UPI'

# %%
#What is the total purchase amount for each payment method?
df.groupby("Payment_Method")["Purchase_Amount"].sum()
# Out:
# Payment_Method
# Cash on Delivery    4276269.38
# Credit Card         4150547.15
# Debit Card          4234776.21
# Net Banking         4063511.41
# PayPal              4173529.85
# UPI                 4259355.65
# Name: Purchase_Amount, dtype: float64

# %%
#Which payment method has the highest average purchase amount?
df.groupby("Payment_Method")["Purchase_Amount"].mean().idxmax()
# Out:
# 'Cash on Delivery'

# %%
#Which product category has the highest total sales?
df.groupby("Product_Category")["Transaction_ID"].count().idxmax()
# Out:
# 'Toys'

# %%
#What is the average purchase amount for the "Electronics" category?
df[df["Product_Category"] == "Electronics"]["Purchase_Amount"].mean()
# Out:
# 495.8805443037975

# %%
#List all transactions for the "Books" category.
df[df["Product_Category"] == 'Books']
# Out:
#        Transaction_ID        User_Name  Age    Country Product_Category  \
# 2                   3  Elijah Thompson   26     France            Books
# 17                 18    Olivia Harris   47     Brazil            Books
# 31                 32     Oliver Allen   30     Canada            Books
# 39                 40     Olivia Allen   60      Japan            Books
# 43                 44      Noah Walker   68         UK            Books
# ...               ...              ...  ...        ...              ...
# 49966           49967      James Lewis   56  Australia            Books
# 49972           49973    Isabella Hall   20     Canada            Books
# 49978           49979  Olivia Anderson   66     France            Books
# 49984           49985     Oliver Clark   25         UK            Books
# 49985           49986     Sophia Lewis   44  Australia            Books
#
#        Purchase_Amount    Payment_Method Transaction_Date
# ...

# %%
#Find the top 5 countries with the highest total purchase amount.
countries_total_purchase = df.groupby('Country')['Purchase_Amount'].sum()
countries_total_purchase.sort_values(ascending = False).head(5)
# Out:
# Country
# France       2545739.19
# Canada       2544335.12
# USA          2541220.22
# Mexico       2534475.67
# Australia    2514911.65
# Name: Purchase_Amount, dtype: float64

# %%
#Calculate the total purchase amount for each user and list the top 10 users.
df.groupby('User_Name')['Purchase_Amount'].sum().sort_values(ascending = False).head(10)
# Out:
# User_Name
# Sophia Harris    296354.98
# James Allen      278079.15
# Olivia Hall      277302.09
# Isabella Hall    275798.04
# Noah Anderson    274347.15
# Emma Clark       274313.60
# Ava Clark        273776.79
# Elijah Hall      271861.61
# James Lewis      271007.68
# Ava Hall         268756.73
# Name: Purchase_Amount, dtype: float64

# %%
#Identify the most popular product category in each country.
country_category = df.groupby(['Country','Product_Category'])['Transaction_ID'].count()
most_popular_category = country_category.groupby(level=0).idxmax()
most_popular_category
# Out:
# Country
# Australia     (Australia, Beauty)
# Brazil             (Brazil, Toys)
# Canada            (Canada, Books)
# France          (France, Grocery)
# Germany         (Germany, Sports)
# India        (India, Electronics)
# Japan             (Japan, Beauty)
# Mexico             (Mexico, Toys)
# UK                     (UK, Toys)
# USA                   (USA, Toys)
# Name: Transaction_ID, dtype: object

# %%
#Find all transactions in the "Clothing" category where the purchase amount is greater than $500.
df[(df['Product_Category'] == "Clothing") & (df['Purchase_Amount'] > 500)]
# Out:
#        Transaction_ID        User_Name  Age    Country Product_Category  \
# 0                   1         Ava Hall   63     Mexico         Clothing
# 44                 45     Elijah Lewis   22     Brazil         Clothing
# 72                 73    Noah Thompson   40         UK         Clothing
# 77                 78        Ava Lewis   28         UK         Clothing
# 96                 97       Noah Clark   61     Mexico         Clothing
# ...               ...              ...  ...        ...              ...
# 49867           49868        Noah Hall   48  Australia         Clothing
# 49891           49892   Emma Rodriguez   36      Japan         Clothing
# 49954           49955  Olivia Thompson   33         UK         Clothing
# 49955           49956    Elijah Walker   62        USA         Clothing
# 49974           49975     Olivia Allen   41     Canada         Clothing
#
#        Purchase_Amount Payment_Method Transaction_Date
# ...

# %%
#Retrieve all transactions made by users from "India" using "UPI" as the payment method.
df[(df["Country"] == "India") & (df["Payment_Method"] == "UPI")]
# Out:
#        Transaction_ID           User_Name  Age Country Product_Category  \
# 52                 53         James Lewis   26   India         Clothing
# 108               109     Olivia Thompson   19   India            Books
# 109               110        Elijah Clark   59   India            Books
# 240               241       Oliver Harris   66   India      Electronics
# 329               330      Liam Rodriguez   31   India         Clothing
# ...               ...                 ...  ...     ...              ...
# 49671           49672     Oliver Anderson   48   India   Home & Kitchen
# 49697           49698       Liam Thompson   63   India           Sports
# 49708           49709      James Anderson   63   India            Books
# 49897           49898        Olivia Clark   36   India            Books
# 49995           49996  Isabella Rodriguez   53   India      Electronics
#
#        Purchase_Amount Payment_Method Transaction_Date
# ...

# %%
#List all transactions for the "Beauty" category made in 2024.
df[(df["Product_Category"] == "Beauty") & (df["Transaction_Date"].dt.year == 2024)]
# Out:
#        Transaction_ID          User_Name  Age    Country Product_Category  \
# 4                   5         Ava Harris   48    Germany           Beauty
# 54                 55  Isabella Anderson   59  Australia           Beauty
# 89                 90       Sophia Allen   69     France           Beauty
# 99                100          Emma Hall   37        USA           Beauty
# 126               127        James White   61     France           Beauty
# ...               ...                ...  ...        ...              ...
# 49946           49947      Elijah Walker   33        USA           Beauty
# 49979           49980         Emma Lewis   32     Mexico           Beauty
# 49983           49984       Elijah Allen   69         UK           Beauty
# 49990           49991    Sophia Anderson   40     Brazil           Beauty
# 49993           49994      Isabella Hall   18     France           Beauty
#
#        Purchase_Amount    Payment_Method Transaction_Date
# ...

# %%
#Check for any missing values in the dataset.
df.isnull().sum()
# Out:
# Transaction_ID      0
# User_Name           0
# Age                 0
# Country             0
# Product_Category    0
# Purchase_Amount     0
# Payment_Method      0
# Transaction_Date    0
# dtype: int64

# %%
#Prepare a summary table of total purchase amounts by country for visualization.
countries_total_purchase = df.groupby('Country')['Purchase_Amount'].sum()
countries_total_purchase.plot(kind = 'bar')
plt.xlabel("Countries")
plt.ylabel("Purchase Amount (USD)")
plt.title("Total purchase amounts by country")
# Out:
# Text(0.5, 1.0, 'Total purchase amounts by country')

# %%
#Create a pivot table showing the total purchase amount by product category and country.

# %%
pivot_table = pd.pivot_table(df, values='Purchase_Amount',index='Product_Category', columns='Country', aggfunc='sum')

# %%
pivot_table
# Out:
# Country           Australia     Brazil     Canada     France    Germany  \
# Product_Category
# Beauty            322842.39  301081.67  296344.51  318036.14  325314.33
# Books             299037.66  319991.03  340734.15  315741.57  321880.00
# Clothing          310470.99  333614.47  322240.55  331622.23  307038.62
# Electronics       316239.62  300502.62  303402.36  323339.62  313067.19
# Grocery           335303.16  308800.17  325693.89  325406.02  301714.95
# Home & Kitchen    299766.52  302600.00  308989.76  309245.89  305286.67
# Sports            319138.22  311645.95  319876.80  318675.91  326127.36
# Toys              312113.09  329051.63  327053.10  303671.81  302013.08
#
# Country               India      Japan     Mexico         UK        USA
# Product_Category
# Beauty            273438.41  323443.64  304326.76  290585.33  301974.61
# Books             323406.10  318447.03  321718.91  304199.39  316741.46
# ...

# %%
#Calculate the standard deviation of purchase amounts for each product category.
df.groupby('Product_Category')['Purchase_Amount'].std()
# Out:
# Product_Category
# Beauty            288.440028
# Books             286.332400
# Clothing          283.178096
# Electronics       286.662288
# Grocery           286.448776
# Home & Kitchen    287.283967
# Sports            287.219531
# Toys              286.816622
# Name: Purchase_Amount, dtype: float64

# %%
#Find the correlation between user age and purchase amount
df['Age'].corr(df['Purchase_Amount'])
# Out:
# -0.0035854517170157093

# %%
#Determine the median purchase amount for each payment method.
df.groupby('Payment_Method')['Purchase_Amount'].median()
# Out:
# Payment_Method
# Cash on Delivery    508.120
# Credit Card         496.375
# Debit Card          503.590
# Net Banking         496.235
# PayPal              513.220
# UPI                 499.810
# Name: Purchase_Amount, dtype: float64

# %%
#Find the transaction with the highest purchase amount.
df.loc[df['Purchase_Amount'].idxmax()]
# Out:
# Transaction_ID                    41015
# User_Name               Sophia Anderson
# Age                                  48
# Country                          France
# Product_Category         Home & Kitchen
# Purchase_Amount                  999.98
# Payment_Method              Credit Card
# Transaction_Date    2024-01-08 00:00:00
# Name: 41014, dtype: object

# %%
#List all transactions made on a specific date (e.g., "2023-04-14").
specific_date = "2023-04-14"
df[df['Transaction_Date'] == specific_date]
# Out:
#        Transaction_ID         User_Name  Age    Country Product_Category  \
# 0                   1          Ava Hall   63     Mexico         Clothing
# 634               635       Noah Harris   45      India             Toys
# 836               837     Elijah Harris   25  Australia      Electronics
# 1116             1117  Elijah Rodriguez   60      India             Toys
# 1666             1667        Emma Clark   49     Mexico             Toys
# ...               ...               ...  ...        ...              ...
# 44343           44344     Olivia Walker   19     France         Clothing
# 44346           44347        Liam Allen   60     France           Beauty
# 47389           47390      Sophia Lewis   32  Australia   Home & Kitchen
# 49797           49798     Ava Rodriguez   30     Brazil           Beauty
# 49980           49981      Olivia White   21     Brazil   Home & Kitchen
#
#        Purchase_Amount    Payment_Method Transaction_Date
# ...

# %%
#Retrieve all transactions where the user's name contains "Harris".
harris_transactions = df[df['User_Name'].str.contains("Harris", case=False, na=False)]
harris_transactions
# Out:
#        Transaction_ID      User_Name  Age    Country Product_Category  \
# 4                   5     Ava Harris   48    Germany           Beauty
# 5                   6  Elijah Harris   51      India             Toys
# 8                   9    Liam Harris   54     France           Beauty
# 12                 13  Sophia Harris   21     France             Toys
# 15                 16  Elijah Harris   55  Australia         Clothing
# ...               ...            ...  ...        ...              ...
# 49958           49959  Olivia Harris   38      India   Home & Kitchen
# 49964           49965  Olivia Harris   70     Brazil            Books
# 49965           49966  Sophia Harris   31        USA   Home & Kitchen
# 49976           49977  Oliver Harris   69     Mexico             Toys
# 49999           50000  Olivia Harris   70     Canada           Sports
#
#        Purchase_Amount    Payment_Method Transaction_Date
# 4               594.83       Net Banking       2024-10-29
# ...
